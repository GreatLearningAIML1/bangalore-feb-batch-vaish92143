# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 4us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
import tensorflow as tf
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
norm_x_train = x_train.astype('float32') / 255
norm_x_test = x_test.astype('float32') / 255

# %%
trainX = norm_x_train.reshape((norm_x_train.shape[0], 28, 28, 1))
testX = norm_x_test.reshape((norm_x_test.shape[0], 28, 28, 1))

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
from keras.models import Sequential
from keras.layers import Dense

# create model
mymodel = tf.keras.models.Sequential()
mymodel.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2,  activation='relu', input_shape=(28,28,1)))
mymodel.add(tf.keras.layers.MaxPooling2D(pool_size=2))
mymodel.add(tf.keras.layers.Dropout(0.25))

mymodel.add(tf.keras.layers.Flatten())
mymodel.add(tf.keras.layers.Dense(200, activation='relu'))
mymodel.add(tf.keras.layers.Dense(100, activation='relu'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0824 14:23:21.343702 140649505654656 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
mymodel.add(tf.keras.layers.Dense(10, activation='softmax'))
mymodel.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
mymodel.fit(trainX, y_train, 
          validation_data=(testX, y_test), 
          epochs=10,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 83s 1ms/sample - loss: 0.8156 - acc: 0.8191 - val_loss: 0.4659 - val_acc: 0.8677
# Epoch 2/10
# 60000/60000 [==============================] - 82s 1ms/sample - loss: 0.3647 - acc: 0.8895 - val_loss: 0.3339 - val_acc: 0.8920
# Epoch 3/10
# 60000/60000 [==============================] - 83s 1ms/sample - loss: 0.2792 - acc: 0.9077 - val_loss: 0.3035 - val_acc: 0.8983
# Epoch 4/10
# 60000/60000 [==============================] - 83s 1ms/sample - loss: 0.2373 - acc: 0.9196 - val_loss: 0.2741 - val_acc: 0.9029
# Epoch 5/10
# 60000/60000 [==============================] - 84s 1ms/sample - loss: 0.2080 - acc: 0.9285 - val_loss: 0.2779 - val_acc: 0.9028
# Epoch 6/10
# 60000/60000 [==============================] - 84s 1ms/sample - loss: 0.1815 - acc: 0.9372 - val_loss: 0.2957 - val_acc: 0.9014
# Epoch 7/10
# 60000/60000 [==============================] - 84s 1ms/sample - loss: 0.1605 - acc: 0.9439 - val_loss: 0.2682 - val_acc: 0.9097
# Epoch 8/10
# 60000/60000 [==============================] - 85s 1ms/sample - loss: 0.1443 - acc: 0.9495 - val_loss: 0.2822 - val_acc: 0.9048
# Epoch 9/10
# 60000/60000 [==============================] - 84s 1ms/sample - loss: 0.1281 - acc: 0.9551 - val_loss: 0.2940 - val_acc: 0.9077
# Epoch 10/10
# 60000/60000 [==============================] - 84s 1ms/sample - loss: 0.1161 - acc: 0.9596 - val_loss: 0.2996 - val_acc: 0.9042

# %%
mymodel_result=mymodel.evaluate(testX,y_test,verbose=1)
# Out:
# 10000/10000 [==============================] - 3s 313us/sample - loss: 0.2996 - acc: 0.9042
